# %%
import json
import os

with open(os.path.join(os.getcwd(), "test.json.data"),'r') as f:
    data = json.load(f)

# %%
data
# Out:
# [{'#url': 'https://vtv.vn',
#   'title': 'Thời báo VTV - Đài Truyền Hình Việt Nam | VTV.vn',
#   'description': 'Mời độc giả đón đọc tin tức thời sự về chính trị, kinh tế, đời sống, xã hội, pháp luật, thể thao, văn hoá, giải trí... Xem truyền hình trực tuyến, TV Online các kênh VTV trên Internet.',
# ...
